# %% [markdown]
# # 🐢 Python Adventure – Level 1: Turtle Exploration
#
# Welcome! Today we’ll learn **Python programming** by helping a turtle friend go on an adventure.
# Your job: give the turtle clear instructions so it can explore, draw, and make art.

# %% [markdown]
# ## 1. Meet Your Turtle Friend 👋

# %%
# Let's greet the world
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# 👉 **Your turn:** Print your name and say hi to the turtle!

# %% [markdown]
# ## 2. Giving the Turtle Memory (Variables) 🧠

# %%
name = "Shelly"      # string (text)
age = 3              # integer (whole number)
speed = 5.5          # float (decimal)
is_happy = True      # boolean (True/False)

print(name, age, speed, is_happy)
# Out:
# Shelly 3 5.5 True

# %% [markdown]
# 👉 **Your turn:** Give your turtle its own **name** and **age**.

# %% [markdown]
# ## 3. Doing Turtle Math ➕➖✖️➗

# %%
hours = 2
minutes = hours * 60
print("Turtle walked for", minutes, "minutes!")
# Out:
# Turtle walked for 120 minutes!

# %% [markdown]
# 👉 **Your turn:** Calculate how many **seconds** are in 5 minutes of turtle walking.

# %% [markdown]
# ## 4. Turtle Choices (If Statements) 🤔

# %%
food = "lettuce"

if food == "lettuce":
    print("Yum! Turtle is happy 🐢🥬")
else:
    print("Hmm... turtle refuses to eat.")
# Out:
# Yum! Turtle is happy 🐢🥬

# %% [markdown]
# 👉 **Your turn:** Check if the turtle sees **water** or **land**, and print a different message for each.

# %% [markdown]
# ## 5. Turtle’s Backpack (Lists) 🎒

# %%
backpack = ["apple", "map", "compass"]
print("Turtle’s first item:", backpack[0])
backpack.append("water bottle")
print("Now the backpack has:", backpack)
# Out:
# Turtle’s first item: apple
# Now the backpack has: ['apple', 'map', 'compass', 'water bottle']

# %% [markdown]
# 👉 **Your turn:** Make a backpack list with 3 items the turtle needs for its trip. Print the second item.

# %% [markdown]
# ## 6. Turtle Steps (Loops) 🔁

# %%
for i in range(5):
    print("Turtle takes step number", i)
# Out:
# Turtle takes step number 0
# Turtle takes step number 1
# Turtle takes step number 2
# Turtle takes step number 3
# Turtle takes step number 4

# %% [markdown]
# 👉 **Your turn:** Write a loop where the turtle counts steps from 1 to 10.

# %% [markdown]
# ## 7. Turtle Tricks (Functions) 🎩

# %%
def greet(name):
    return "Hello, " + name + "! 🐢"

print(greet("Shelly"))
# Out:
# Hello, Shelly! 🐢

# %% [markdown]
# 👉 **Your turn:** Teach the turtle a function `double(n)` that returns twice a number.

# %% [markdown]
# # Part 2: The Turtle Adventure Map 🌍🐢

# %% [markdown]
# ## 8. Setting up the Map

# %%
# !pip install ColabTurtlePlus
from ColabTurtlePlus.Turtle import *

initializeTurtle()
# Out:
# ...
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#
#
#
#
#       </svg>

# %% [markdown]
# ## 9. The Turtle Moves!

# %%
reset()
forward(100)
right(90)
forward(50)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="500.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="500.0" y1="300.0" x2="500.0" y2="310.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="500.0" y1="310.0" x2="500.0" y2="320.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="500.0" y1="320.0" x2="500.0" y2="330.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="500.0" y1="330.0" x2="500.0" y2="340.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="500.0" y1="340.0" x2="500.0" y2="350.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(0,500.0,350.0) translate(500.0, 350.0)">
# ...

# %% [markdown]
# 👉 **Your turn:** Make the turtle walk in an **L shape**.

# %% [markdown]
# ## 10. The Turtle Builds a Hut ⬛

# %%
reset()
for i in range(4):
    forward(100)
    right(90)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="500.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="500.0" y1="300.0" x2="500.0" y2="400.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="500.0" y1="400.0" x2="400.0" y2="400.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="400.0" y1="400.0" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(180,400.0,300.0) translate(400.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# <animateTransform id = "one" attributeName="transform"
#                       type="scale"
#                       from="1 1" to="1 1"
# ...

# %% [markdown]
# 👉 **Your turn:** Change the number of sides – can you build a **triangle tent** or a **hexagon hut**?

# %% [markdown]
# ## 11. The Turtle Learns Geometry 📐

# %%
reset()
sides = 6
length = 70

for i in range(sides):
    forward(length)
    right(360 / sides)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="470.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="470.0" y1="300.0" x2="505.0" y2="360.622" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="505.0" y1="360.622" x2="470.0" y2="421.244" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="470.0" y1="421.244" x2="400.0" y2="421.244" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="400.0" y1="421.244" x2="365.0" y2="360.622" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="365.0" y1="360.622" x2="400.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(210.0,400.0,300.0) translate(400.0, 300.0)">
# ...

# %% [markdown]
# 👉 **Your turn:** Try different values of `sides`. What shapes does your turtle make?

# %% [markdown]
# ## 12. The Turtle’s Magic Spell ✨

# %%
reset()
def draw_shape(sides, length):
    for i in range(sides):
        forward(length)
        right(360 / sides)

draw_shape(8, 40)  # Turtle draws an octagon spell
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %% [markdown]
# 👉 **Your turn:** Call `draw_shape(5, 100)` to make a star-like path.

# %% [markdown]
# ## 13. Turtle Fireworks 🎆

# %%
reset()
speed(10)

for i in range(50):
    forward(i * 5)
    right(45)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %% [markdown]
# 👉 **Your turn:** Change `45` to another angle. What kind of fireworks does your turtle make?

# %% [markdown]
# # 🎯 Wrap-up
#
# Today you helped your turtle friend:
#
# ✅ Say hello
#
# ✅ Remember things with variables
#
# ✅ Do math
#
# ✅ Make choices
#
# ✅ Carry a backpack (lists)
#
# ✅ Walk in loops
#
# ✅ Learn tricks (functions)
#
# ✅ Explore the world with Turtle graphics
#
# 🌟 You are now a **Python Turtle Explorer**! 🐢💻🎨
