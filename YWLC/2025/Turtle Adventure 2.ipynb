# %% [markdown]
# <div style="border: 2px solid #f4b400; border-radius: 10px; background-color: #fff8e1; padding: 1em;">
#
# <h3>⚠️ Before You Start</h3>
#
# <p><strong>Make a copy of this notebook before running any code!</strong></p>
#
# <ol>
#   <li>Click <b>File → Save a copy in Drive</b></li>
#   <li>A new notebook will open — that’s <b>your own copy</b> 🎉</li>
#   <li>You can rename it (e.g. <code>Turtle_Adventure_2_YourName</code>)</li>
# </ol>
#
# </div>

# %% [markdown]
# # 🐢 Python Adventure – Level 2: Turtle Challenges
#
# 🎯 **Goal**: Practice Python programming concepts through creative turtle challenges.
# You already know variables, loops, conditionals, functions, and lists – now let’s put them into action!

# %% [markdown]
# ## Setup Turtle Environment

# %%
# !pip install ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
initializeTurtle()

# %% [markdown]
# ## 1. If-Else Challenge – What does Turtle eat?
#
# Write a function that determines what to feed your turtle depending on how much energy she has.
#
# Her `energy` level ranges from 0 to 10.
# * 🍕 If she's very low energy (3 and below), feed her *pizza*.
# * 🍎 If she's slightly low (4 to 6), feed her an *apple*.
# * 🌱 If she's not really hungry, feed her a *leaf*.
#
# Feel free to modify the hunger thresholds and food items as you like!

# %%
from random import randint

# 👉 Your turn! Complete the what_to_eat function here

def what_to_eat(energy):
  print(f"Turtle's hunger level is {energy}.")

  # if-elif-else code to determine what to eat

  print(f"You decided to feed the turtle {food}.")

# Try it
energy = randint(0, 10)
what_to_eat(energy)

# %% [markdown]
# ## 2. Lists Challenge – Turtle Rain Check
# Turtle is planning her trip. She checks the weather for the next 6 days.
# * If it's **sunny**, she'll paste a *yellow* sticker.
# * If it's **rainy**, she'll paste a *blue* sticker to remember her umbrella.
# * Otherwise, she'll paste a *grey* sticker.
#
# Hint: You can use `dot()` to draw a circle to represent the sticker, and `pencolor(color)` to change colors.

# %%
# Setup
initializeTurtle()
speed(8)
penup()
goto(-250, 0)
pendown()

# Weather forecast
weather_list = ['sunny', 'rainy', 'cloudy', 'windy', 'sunny', 'rainy']

# === Exercise: react based on weather ===
for weather in weather_list:
    # TODO: write your if-elif-else logic here!
    # - sunny → yellow dot
    # - rainy → blue dot
    # - otherwise → gray dot
    forward(80)

# %% [markdown]
# ## 3. Operators Challenge – Turtle Calculator
# Write a function that calculates steps = minutes × speed and makes the turtle walk that distance.
# If energy < steps, turtle should stop early.

# %%
clearscreen()
# 👉 Your turn! Write the turtle_calculator function here
energy = 50

def turtle_calculator(minutes, speed):
  pass

# Example:
turtle_calculator(10, 7)

# %% [markdown]
# ## 4. Loops Challenge -🐢 Turtle’s Survival Adventure
#
# Our turtle is going on a long 6-day journey!
# She starts with a certain HP (Health Points) between 5 and 10 and a bag of food items.
#
# Each day, she:
# * Loses 3 HP from traveling.
# * Can eat something if she still has food in her bag to restore energy.
#
# The journey ends when:
# * She finishes all 6 days, or
# * She runs out of food.

# %%
import random

# Starting stats
energy = random.randint(5, 10)
bag = ['leaf', 'apple', 'pizza', 'apple', 'leaf']
day = 1

print("🐢 Turtle begins her 6-day adventure!")
print(f"Starting energy: {energy}")
print(f"Food bag: {bag}")

# %%
# TODO: Fill in the loop logic

while day <= 6 and len(bag) > 0:
    print(f"\n--- Day {day} ---")

    # Lose 3 energy from travel


    # Eat food if available


    # Restore energy based on food type


    print(f"Turtle’s energy level after eating: {energy}")
    print(f"Food left: {bag}")

    # Move to next day
    day += 1

print("\nJourney complete!")

# %% [markdown]
# ## 5. Functions Challenge – Discovering a Turtle Village
#
# Turtle didn't bring enough food 🍽️😩
#
# Luckily, she stumbled upon a village full of other turtles!
#
# Function `draw_house(size)` draws a square house with a triangle roof. Draw 8 houses in a circle.

# %%
clearscreen()
# 👉 Your turn! Implement draw_house and village
def draw_house(size):
    for _ in range(4):
        forward(size)
        right(90)
    left(45)
    for _ in range(2):
        forward(size / 1.414)
        right(90)
    right(180)

def draw_village():
  for _ in range(8):
      draw_house(50)
      penup()
      forward(60)
      pendown()

draw_house(50)

# %% [markdown]
# ## 7. Celebrate – Turtle Makes Fireworks 🎆
#
# The turtle village chief feeds her and throws a celebration with the whole viillage.
#
# Draw a polygon repeatedly in a circle to create a mandala.
# Bonus: change colors.
#
# ### Example:
# ![Screenshot 2025-10-10 at 1.40.08 AM.png](data:image/png;base64,...)

# %%
# 👉 Your turn! Implement the draw_fireworks function
import random

def draw_fireworks(sides, length):
    pass

# %% [markdown]
# # 🌟 Wrap-Up: What You’ve Learned on Turtle’s Journey
#
# Wow! 🎉 Turtle made it through her long 6-day adventure (or maybe... she didn’t 😅).
# Either way, you just helped her make important decisions using Python logic! 🐢💚
#
# Here’s what you practiced in this challenge:
#
# ✅ while loops — to repeat actions for each day of the journey
#
# ✅ if-elif-else conditions — to decide what happens depending on the food type
#
# ✅ lists — to store and remove food from Turtle’s bag
#
# ✅ variables — to track energy, days, and inventory changes
#
# ✅ random numbers — to make each adventure different and exciting!
#
# That’s everything a Python adventurer needs to start thinking like a game designer 🧠🎮
